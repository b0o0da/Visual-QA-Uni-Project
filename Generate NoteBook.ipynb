# %%
import pandas as pd
df = pd.read_csv('visual_qa_rows200_to_end.csv')
df
# Out:
#                                    image_path  \
# 0       dataset_images/pixabay_person_4_2.jpg
# 1       dataset_images/pixabay_person_4_2.jpg
# 2       dataset_images/pixabay_person_4_2.jpg
# 3       dataset_images/pixabay_person_4_2.jpg
# 4       dataset_images/pixabay_person_4_2.jpg
# ...                                       ...
# 47060  dataset_images/unsplash_clock_1_29.jpg
# 47061  dataset_images/unsplash_clock_1_29.jpg
# 47062  dataset_images/unsplash_clock_1_29.jpg
# 47063  dataset_images/unsplash_clock_1_29.jpg
# 47064  dataset_images/unsplash_clock_1_29.jpg
#
#                                                image_url    source   topic  \
# 0      https://pixabay.com/get/gea0ae91b489bcc79bab4d...   pixabay  person
# 1      https://pixabay.com/get/gea0ae91b489bcc79bab4d...   pixabay  person
# 2      https://pixabay.com/get/gea0ae91b489bcc79bab4d...   pixabay  person
# 3      https://pixabay.com/get/gea0ae91b489bcc79bab4d...   pixabay  person
# ...
